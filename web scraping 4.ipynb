# %%
import selenium 
from selenium import webdriver 
import pandas as pd
from bs4 import BeautifulSoup
import requests
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC

# %% [raw]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")

# %%
url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'

# %%
driver.get(url)

# %%
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
r=driver.find_elements_by_xpath(r"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[1]")
for i in r:
    Rank.append(i.text)
    
    
Rank[:5]
# Out:
# ['1.', '2.', '3.', '4.', '5.']

# %%
v_name=driver.find_elements_by_xpath(r"//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[2]")
for i in v_name:
    Name.append(i.text)
    
    
Name[:5]
# Out:
# ['"Baby Shark Dance"[28]',
#  '"Despacito"[30]',
#  '"Shape of You"[31]',
#  '"See You Again"[32]',
#  '"Johny Johny Yes Papa"[35]']

# %%
data=driver.find_elements_by_xpath(r"//td[@align='right']")
for i in data:
    Upload_date.append(i.text)

Upload_date[:5]
# Out:
# ['June 17, 2016',
#  'January 12, 2017',
#  'January 30, 2017',
#  'April 6, 2015',
#  'October 8, 2016']

# %%
v=driver.find_elements_by_xpath(r"//div[@id='mw-content-text']/div[1]/table[1]/tbody/tr/td[4]")
for i in v:
    Views.append(i.text)
    
Views[:5]
# Out:
# ['7.91', '7.20', '5.18', '4.96', '4.77']

# %%
a=driver.find_elements_by_xpath(r"//div[@id='mw-content-text']/div[1]/table[1]/tbody/tr/td[3]")
for i in a:
    Artist.append(i.text)
    
Artist
# Out:
# ["Pinkfong Kids' Songs & Stories",
#  'Luis Fonsi featuring Daddy Yankee',
#  'Ed Sheeran',
#  'Wiz Khalifa featuring Charlie Puth',
#  'LooLoo Kids',
#  'Get Movies',
#  'Mark Ronson featuring Bruno Mars',
#  'Psy',
#  'Miroshka TV',
#  'Cocomelon – Nursery Rhymes',
#  'ChuChu TV',
#  'Justin Bieber',
#  'Maroon 5',
#  'Katy Perry',
#  'OneRepublic',
#  'Ed Sheeran',
#  'El Chombo featuring Cutty Ranks',
#  'Taylor Swift',
#  'Alan Walker',
#  'Major Lazer and DJ Snake featuring MØ',
#  'Enrique Iglesias featuring Descemer Bueno and Gente De Zona',
#  'Katy Perry featuring Juicy J',
#  'Maroon 5 featuring Cardi B',
#  'Passenger',
#  'J Balvin and Willy William',
#  'Adele',
#  'Ed Sheeran',
#  'Shakira featuring Freshlyground',
#  'Taylor Swift',
#  'Shakira featuring Maluma']

# %%
print(len(Name),len(Artist),len(Rank),len(Views),len(Upload_date))
# Out:
# 49 30 49 30 87

# %%
song=pd.DataFrame({})
song['Rank']=Rank[:30]
song['Video name']=Name[:30]
song['Artist name']=Artist[:30]
song['View ']=Views[:30]
song['Date']=Upload_date[:30]
song
# Out:
#    Rank                                       Video name  \
# 0    1.                           "Baby Shark Dance"[28]
# 1    2.                                  "Despacito"[30]
# 2    3.                               "Shape of You"[31]
# 3    4.                              "See You Again"[32]
# 4    5.                       "Johny Johny Yes Papa"[35]
# 5    6.   "Masha and the Bear – Recipe for Disaster"[36]
# 6    7.                                "Uptown Funk"[37]
# 7    8.                              "Gangnam Style"[38]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[40]
# 9   10.                                  "Bath Song"[41]
# 10  11.                "Phonics Song with Two Words"[42]
# 11  12.                                      "Sorry"[43]
# 12  13.                                      "Sugar"[44]
# 13  14.                                       "Roar"[45]
# 14  15.                             "Counting Stars"[46]
# ...

# %% [raw]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")

# %%
url='https://www.bcci.tv'

# %%
driver.get(url)

# %%
button = driver.find_element_by_xpath('//div[@class="drop-down__options"]/ul/li/a').get_attribute('href')
driver.get(button)

# %%
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]
Month=[]

# %%
title=driver.find_elements_by_xpath(r"//p[@class='fixture__additional-info']/strong")
for i in title:
    Match_title.append(i.text)
    
Match_title
# Out:
# ['2nd Test',
#  '3rd Test',
#  '4th Test',
#  '1st T20I',
#  '2nd T20I',
#  '3rd T20I',
#  '4th T20I',
#  '5th T20I',
#  '1st ODI',
#  '2nd ODI',
#  '3rd ODI',
#  '1st Test',
#  '2nd Test',
#  '3rd Test',
#  '4th Test',
#  '5th Test']

# %%
venue=driver.find_elements_by_xpath(r"//p[@class='fixture__additional-info']/span")
for i in venue:
    Place.append(i.text)
    
Place
# Out:
# ['M. A. Chidambaram Stadium, Chennai',
#  'Sardar Patel Stadium, Ahmedabad',
#  'Sardar Patel Stadium, Ahmedabad',
#  'Sardar Patel Stadium, Ahmedabad',
#  'Sardar Patel Stadium, Ahmedabad',
#  'Sardar Patel Stadium, Ahmedabad',
#  'Sardar Patel Stadium, Ahmedabad',
#  'Sardar Patel Stadium, Ahmedabad',
#  'Maharashtra Cricket Association Stadium, Pune',
#  'Maharashtra Cricket Association Stadium, Pune',
#  'Maharashtra Cricket Association Stadium, Pune',
#  'Trent Bridge, Nottingham',
#  "Lord's, London",
#  'Headingley, Leeds',
#  'The Oval, London',
#  'Old Trafford, Manchester']

# %%
name=driver.find_elements_by_xpath(r"//span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
for i in name:
    Series.append(i.text)
    
Series
# Out:
# ['INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'INDIA V ENGLAND 2021',
#  'ENGLAND V INDIA 2021',
#  'ENGLAND V INDIA 2021',
#  'ENGLAND V INDIA 2021',
#  'ENGLAND V INDIA 2021',
#  'ENGLAND V INDIA 2021']

# %%
m_time=driver.find_elements_by_xpath(r"//span[@class='fixture__time']")
for i in m_time:
    Time.append(i.text)
    
Time
# Out:
# ['09:30 IST',
#  '14:30 IST',
#  '09:30 IST',
#  '19:00 IST',
#  '19:00 IST',
#  '19:00 IST',
#  '19:00 IST',
#  '19:00 IST',
#  '13:30 IST',
#  '13:30 IST',
#  '13:30 IST',
#  '15:30 IST',
#  '15:30 IST',
#  '15:30 IST',
#  '15:30 IST',
#  '15:30 IST']

# %%
m_month=driver.find_elements_by_xpath(r"//span[@class='fixture__month']")
for i in m_month:
    Month.append(i.text)
    
Month
# Out:
# ['FEBRUARY',
#  'FEBRUARY',
#  'MARCH',
#  'MARCH',
#  'MARCH',
#  'MARCH',
#  'MARCH',
#  'MARCH',
#  'MARCH',
#  'MARCH',
#  'MARCH',
#  'AUGUST',
#  'AUGUST',
#  'AUGUST',
#  'SEPTEMBER',
#  'SEPTEMBER']

# %%
day=driver.find_elements_by_xpath(r"//span[@class='fixture__date']")
for i in day:
    Date.append(i.text)
    
Date
# Out:
# ['13',
#  '24',
#  '04',
#  '12',
#  '14',
#  '16',
#  '18',
#  '20',
#  '23',
#  '26',
#  '28',
#  '04',
#  '12',
#  '25',
#  '02',
#  '10']

# %%
print(len(Match_title),len(Series),len(Place),len(Date),len(Month),len(Time))
# Out:
# 16 16 16 16 16 16

# %%
Fixture=pd.DataFrame({})
Fixture['MATCH TITLE']=Match_title
Fixture['SERIES']=Series
Fixture['PLACE']=Place
Fixture['DATE']=Date
Fixture['MONTH']=Month
Fixture['TIME']=Time
Fixture
# Out:
#    MATCH TITLE                SERIES  \
# 0     2nd Test  INDIA V ENGLAND 2021
# 1     3rd Test  INDIA V ENGLAND 2021
# 2     4th Test  INDIA V ENGLAND 2021
# 3     1st T20I  INDIA V ENGLAND 2021
# 4     2nd T20I  INDIA V ENGLAND 2021
# 5     3rd T20I  INDIA V ENGLAND 2021
# 6     4th T20I  INDIA V ENGLAND 2021
# 7     5th T20I  INDIA V ENGLAND 2021
# 8      1st ODI  INDIA V ENGLAND 2021
# 9      2nd ODI  INDIA V ENGLAND 2021
# 10     3rd ODI  INDIA V ENGLAND 2021
# 11    1st Test  ENGLAND V INDIA 2021
# 12    2nd Test  ENGLAND V INDIA 2021
# 13    3rd Test  ENGLAND V INDIA 2021
# 14    4th Test  ENGLAND V INDIA 2021
# 15    5th Test  ENGLAND V INDIA 2021
#
#                                             PLACE DATE      MONTH       TIME
# 0              M. A. Chidambaram Stadium, Chennai   13   FEBRUARY  09:30 IST
# 1                 Sardar Patel Stadium, Ahmedabad   24   FEBRUARY  14:30 IST
# 2                 Sardar Patel Stadium, Ahmedabad   04      MARCH  09:30 IST
# ...

# %% [raw]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")

# %%
url='https://www.guru99.com'

# %%
driver.get(url)

# %%
s_button = driver.find_element_by_xpath('//li[@class="g-dropdown-column"]/div/div[3]/ul/li[5]/a').get_attribute('href')
driver.get(s_button)

# %%
n_button = driver.find_element_by_xpath('//div[@class="item-page"]/div[2]/table[5]/tbody/tr[34]/td/a').get_attribute('href')
driver.get(n_button)

# %%
name=[]
des=[]

# %%
title=driver.find_elements_by_xpath(r"//table[@class='table table-striped']/tbody/tr[42]/td[1]")
for i in title:
    name.append(i.text)

    
print(name)
# Out:
# ['ElementNotVisibleException', 'ElementNotSelectableException', 'NoSuchElementException', 'NoSuchFrameException', 'NoAlertPresentException', 'NoSuchWindowException', 'StaleElementReferenceException', 'SessionNotFoundException', 'TimeoutException', 'WebDriverException', 'ConnectionClosedException', 'ElementClickInterceptedException', 'ElementNotInteractableException', 'ErrorInResponseException', 'ErrorHandler.UnknownServerException', 'ImeActivationFailedException', 'ImeNotAvailableException', 'InsecureCertificateException', 'InvalidArgumentException', 'InvalidCookieDomainException', 'InvalidCoordinatesException', 'InvalidElementStateExceptio', 'InvalidSessionIdException', 'InvalidSwitchToTargetException', 'JavascriptException', 'JsonException', 'NoSuchAttributeException', 'MoveTargetOutOfBoundsException', 'NoSuchContextException', 'NoSuchCookieException', 'NotFoundException', 'RemoteDriverServerException', 'ScreenshotException', 'SessionNotCreatedException', 'UnableToSetCookieExceptio
# ...

# %%
exp_des=driver.find_elements_by_xpath(r"//table[@class='table table-striped']/tbody/tr[42]/td[2]")
for i in exp_des:
    des.append(i.text)

    
des
# Out:
# ['This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  'This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  'This Exception occurs if an element could not be found.',
#  'This Exception occurs if the frame target to be switched to does not exist.',
#  'This Exception occurs when you switch to no presented alert.',
#  'This Exception occurs if the window target to be switch does not exist.',
#  'This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  'The WebDriver is acting after you quit the browser.',
#  "Thrown when there is not enough time for a command to be completed. For Example, the element searched wasn't found in the specified time.",
#  'This Exception takes place when the WebDriver is acting right after you close the browser.',
# ...

# %%
print(len(name),len(des))
# Out:
# 41 41

# %%
selenium=pd.DataFrame({})
selenium['Exception name']=name
selenium['Description']=des
selenium
# Out:
#                          Exception name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [raw]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")

# %%
driver.get('http://statisticstimes.com')

# %%
i_button = driver.find_element_by_xpath('//div[@class="dropdown-content"]/a[3]').get_attribute('href')
driver.get(i_button)

# %%
delay = 5
try:
    s_button = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').get_attribute('href')
    driver.get(s_button)
except TimeoutException as e:
    print('Expection Raised',e)

# %%
rank=[]
state=[]
GSDP89=[]
GSDP78=[]
Share_17=[]
GDP=[]

# %%
rating=driver.find_elements_by_xpath(r"//table[@id='table_id']/tbody/tr/td[1]")
for i in rating:
    rank.append(i.text)
    
rank[:5]
# Out:
# ['1', '2', '3', '4', '5']

# %%
gs_1=driver.find_elements_by_xpath(r"//table[@id='table_id']/tbody/tr/td[3]")
for i in gs_1:
    GSDP89.append(i.text)
    
GSDP89[:5]
# Out:
# ['-', '1,794,508', '1,845,853', '1,699,115', '-']

# %%
gs_2=driver.find_elements_by_xpath(r"//table[@id='table_id']/tbody/tr/td[4]")
for i in gs_2:
    GSDP78.append(i.text)
    
GSDP78[:5]
# Out:
# ['2,632,792', '1,668,229', '1,630,208', '1,544,399', '1,502,899']

# %%
name=driver.find_elements_by_xpath(r"//table[@id='table_id']/tbody/tr/td[2]")
for i in name:
    state.append(i.text)
    
state[:5]
# Out:
# ['Maharashtra', 'Uttar Pradesh', 'Tamil Nadu', 'Karnataka', 'Gujarat']

# %%
s_17=driver.find_elements_by_xpath(r"//table[@id='table_id']/tbody/tr/td[5]")
for i in s_17:
    Share_17.append(i.text)
    
Share_17[:5]
# Out:
# ['13.88%', '8.79%', '8.59%', '8.14%', '7.92%']

# %%
g=driver.find_elements_by_xpath(r"//table[@id='table_id']/tbody/tr/td[6]")
for i in g:
    GDP.append(i.text)
    
GDP[:5]
# Out:
# ['398.145', '252.278', '246.529', '233.552', '227.276']

# %%
print(len(Rank),len(state),len(GSDP89),len(GSDP78),len(Share_17),len(GDP))
# Out:
# 49 66 66 66 66 66

# %%
sw=pd.DataFrame({})
sw['Rank']=Rank[:30]
sw['State']=state[:30]
sw['GSDP(18-19)']=GSDP89[:30]
sw['GSDP(17-18)']=GSDP78[:30]
sw['Share(2017)']=Share_17[:30]
sw['GDP($ billion)']=GDP[:30]
sw
# Out:
#    Rank             State GSDP(18-19) GSDP(17-18) Share(2017) GDP($ billion)
# 0    1.       Maharashtra           -   2,632,792      13.88%        398.145
# 1    2.     Uttar Pradesh   1,794,508   1,668,229       8.79%        252.278
# 2    3.        Tamil Nadu   1,845,853   1,630,208       8.59%        246.529
# 3    4.         Karnataka   1,699,115   1,544,399       8.14%        233.552
# 4    5.           Gujarat           -   1,502,899       7.92%        227.276
# 5    6.       West Bengal   1,253,832   1,089,898       5.75%        164.820
# 6    7.         Rajasthan   1,020,989     942,586       4.97%        142.543
# 7    8.    Andhra Pradesh     972,782     862,957       4.55%        130.501
# 8    9.         Telangana     969,604     861,031       4.54%        130.210
# 9   10.    Madhya Pradesh     906,672     809,592       4.27%        122.431
# 10  11.            Kerala           -     781,653       4.12%        118.206
# ...

# %% [raw]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")

# %%
url='https://github.com'

# %%
driver.get(url)

# %%
Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_used=[]

# %%
t_button = driver.find_element_by_xpath('//div[@class="dropdown-menu flex-auto rounded-1 bg-white px-0 pt-2 pb-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4"]/ul[2]/li[3]/a').get_attribute('href')
driver.get(t_button)

# %%
title=driver.find_elements_by_xpath(r"//h1[@class='h3 lh-condensed']")
for i in title:
    Repository_title.append(i.text)

des=driver.find_elements_by_xpath(r"//p[@class='col-9 text-gray my-1 pr-4']")
for i in des:
    Repository_description.append(i.text)
    
lang=driver.find_elements_by_xpath(r"//div[@class='f6 text-gray mt-2']/span/span[2]")
for i in lang:
    Language_used.append(i.text)
    
count=driver.find_elements_by_xpath(r"//div[@class='f6 text-gray mt-2']/a[1]")    
for i in count:
    Contributors_count.append(i.text)

# %%
print(len(Repository_title),len(Repository_description),len(Language_used),len(Contributors_count))
# Out:
# 25 23 22 25

# %%
github=pd.DataFrame({})
github['Repository title']=Repository_title[:20]
github['Repository description']=Repository_description[:20]
github['Language used']=Language_used[:20]
github['Contributors count']=Contributors_count[:20]
github
# Out:
#                          Repository title  \
# 0          JonnyBurger / remotion-trailer
# 1         iam-abbas / Reddit-Stock-Trends
# 2                       hashicorp / vault
# 3                      conwnet / github1s
# 4      Azure / azure-quickstart-templates
# 5              Kaiyiwing / qwerty-learner
# 6                  JonnyBurger / remotion
# 7    nemanjarogic / DesignPatternsLibrary
# 8             tgbot-collection / YYeTsBot
# 9         aws / amazon-sagemaker-examples
# 10         jomjol / AI-on-the-edge-device
# 11       goldbergyoni / nodebestpractices
# 12                  streamich / react-use
# 13  ryanmcdermott / clean-code-javascript
# 14         charliegerard / gaze-detection
# 15           mozilla-mobile / firefox-ios
# 16       dkhamsing / open-source-ios-apps
# 17                         justjavac / 1s
# 18                       nandorojo / moti
# 19                      sveltejs / svelte
#
# ...

# %% [raw]
# 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https://www.billiboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
Song_name=[]
Artist_name=[]
Last_week=[]
Peak=[]
Weeks=[]

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")
delay = 5
try:
    driver.get('https://www.billboard.com')
except TimeoutException as e:
    print('Expection Raised',e)

# %%
c_button = driver.find_element_by_xpath('//ul[@class="header__submenu__list"]/li[1]/a').get_attribute('href')
driver.get(c_button)

# %%
s_name=driver.find_elements_by_xpath(r"//span[@class='chart-element__information__song text--truncate color--primary']")
for i in s_name:
    Song_name.append(i.text)
    
a_name=driver.find_elements_by_xpath(r"//span[@class='chart-element__information__artist text--truncate color--secondary']")
for i in a_name:
    Artist_name.append(i.text)
    
    
l_week=driver.find_elements_by_xpath(r"//div[@class='chart-element__meta text--center color--secondary text--last']")
for i in l_week:
    Last_week.append(i.text)
    
rank=driver.find_elements_by_xpath(r"//div[@class='chart-element__meta text--center color--secondary text--peak']")
for i in rank:
    Peak.append(i.text)
    
    
n_week=driver.find_elements_by_xpath(r"//div[@class='chart-element__meta text--center color--secondary text--week']")
for i in n_week:
    Weeks.append(i.text)

# %%
print(len(Song_name),len(Artist_name),len(Last_week),len(Peak),len(Weeks))
# Out:
# 100 100 100 100 100

# %%
songs=pd.DataFrame({})
songs['Song name']=Song_name
songs['Artist name']=Artist_name
songs['Last week rank']=Last_week
songs['Peak rank']=Peak
songs['Weeks on board']=Weeks
songs
# Out:
#           Song name                               Artist name Last week rank  \
# 0   Drivers License                            Olivia Rodrigo              1
# 1              Mood              24kGoldn Featuring iann dior              2
# 2   Blinding Lights                                The Weeknd              3
# 3             34+35                             Ariana Grande              4
# 4        Levitating                 Dua Lipa Featuring DaBaby              5
# ..              ...                                       ...            ...
# 95        Fake Woke                             Tom MacDonald              -
# 96         Prisoner            Miley Cyrus Featuring Dua Lipa             81
# 97        Dangerous                             Morgan Wallen              -
# 98    Almost Maybes                              Jordan Davis              -
# 99    Mr. Right Now  21 Savage & Metro Boomin Featuring Drake             80
#
#    Peak rank Weeks on board
# ...

# %% [raw]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
url='https://www.naukri.com'

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")
driver.get(url)

# %%
r_button=driver.find_element_by_xpath('//ul[@class="midSec menu"]/li[2]/div/ul/li[1]/a').get_attribute('href')   
driver.get(r_button)

# %%
search_bar = driver.find_element_by_xpath('//input[@class="sugInp"]')
search_bar.send_keys('Data scientist')
search_button = driver.find_element_by_xpath('//button[@class="fl qsbSrch blueBtn"]')       
search_button.click()

# %%
Name=[]
Designation=[]
Company=[]
Skills=[]
Location=[]

# %%
n=driver.find_elements_by_xpath(r"//span[@class='fl ellipsis']")
for i in n:
    Name.append(i.text)
d=driver.find_elements_by_xpath(r"//span[@class='ellipsis clr']")
for i in d:
    Designation.append(i.text)

c=driver.find_elements_by_xpath(r"//p[@class='highlightable']/a[2]")
for i in c:
    Company.append(i.text)

s=driver.find_elements_by_xpath(r"//div[@class='hireSec highlightable']")
for i in s:
    Skills.append(i.text)
    

l=driver.find_elements_by_xpath(r"//small[@class='ellipsis']")
for i in l:
    Location.append(i.text)

# %%
print(len(Name),len(Designation),len(Company),len(Skills),len(Location))
# Out:
# 50 50 50 50 49

# %%
naukri=pd.DataFrame({})
naukri['Name']=Name[:49]
naukri['Designation']=Designation[:49]
naukri['Company']=Company[:49]
naukri['Skills']=Skills[:49]
naukri['Location']=Location[:49]
naukri
# Out:
#                                             Name  \
# 0                                      Tanushree
# 1                                  sashi bhushan
# 2                                         Bitapi
# 3                                 Gajendra Singh
# 4                              Sadashiv Kulkarni
# 5                                    Invelopment
# 6                              Anjali Srivastava
# 7                                Anoop Somarajan
# 8                                     Helly Vyas
# 9                                   Ashish Verma
# 10                              Bhuwneshari Devi
# 11                                        Naresh
# 12                                    HS Sandesh
# 13                                   Datafoundry
# 14                               A Valsa Florina
# 15                                 Kalaivani M V
# 16                                    Prashant K
# 17                                       Radhika
# ...

# %% [raw]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")

# %%
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'

# %%
driver.get(url)

# %%
Book_name=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]

# %%
name=driver.find_elements_by_xpath(r"//table[@class='in-article sortable']/tbody/tr/td[2]")
for i in name:
    Book_name.append(i.text)
    
a=driver.find_elements_by_xpath(r"//table[@class='in-article sortable']/tbody/tr/td[3]")
for i in a:
    Author_name.append(i.text)

vol=driver.find_elements_by_xpath(r"//table[@class='in-article sortable']/tbody/tr/td[4]")
for i in vol:
    Volumes_sold.append(i.text)

p=driver.find_elements_by_xpath(r"//table[@class='in-article sortable']/tbody/tr/td[5]")
for i in p:
    Publisher.append(i.text)
    

g=driver.find_elements_by_xpath(r"//table[@class='in-article sortable']/tbody/tr/td[6]")
for i in g:
    Genre.append(i.text)

# %%
print(len(Book_name),len(Author_name),len(Volumes_sold),len(Publisher),len(Genre))
# Out:
# 100 100 100 100 100

# %%
novels=pd.DataFrame({})
novels['Book name']=Book_name
novels['Author name']=Author_name
novels['Volumes sold']=Volumes_sold
novels['Publisher']=Publisher
novels['Genre']=Genre
novels
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %% [raw]
# 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")

# %%
Url = 'https://www.imdb.com/list/ls095964455'

# %%
driver.get(Url)

# %%
Name=[]
Year=[]
Genre=[]
time=[]
Ratings=[]
Votes=[]

# %%
title=driver.find_elements_by_xpath(r"//h3[@class='lister-item-header']/a")
for i in title:
    Name.append(i.text)
    
y=driver.find_elements_by_xpath(r"//span[@class='lister-item-year text-muted unbold']")
for i in y:
    Year.append(i.text)

t=driver.find_elements_by_xpath(r"//span[@class='runtime']")
for i in t:
    time.append(i.text)

r=driver.find_elements_by_xpath(r"//span[@name='nv']")
for i in r:
    Ratings.append(i.text)
    

g=driver.find_elements_by_xpath(r"//span[@class='genre']")
for i in g:
    Genre.append(i.text)

    
v=driver.find_elements_by_xpath(r"//div[@class='lister-item-content']/p[4]/span[2]")
for i in v:
    Votes.append(i.text)

# %%
print(len(Name),len(Year),len(time),len(Ratings),len(Genre),len(Votes))
# Out:
# 100 100 100 100 100 100

# %%
series=pd.DataFrame({})
series['Name']=Name
series['Year span']=Year
series['Genre']=Genre
series['Run time']=time
series['Ratings']=Ratings
series['Votes']=Votes
series
# Out:
#                               Name    Year span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead     (2010– )   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Crime, Drama, Horror
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time    Ratings      Votes
# 0    57 min  1,768,783  1,768,783
# ...

# %% [raw]
# 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
url='https://archive.ics.uci.edu'

# %%
driver=webdriver.Chrome(r"C:\Users\Dell Laptop\chromedriver.exe")

# %%
driver.get(url)

# %%
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
instances=[]
attribute=[]
Year=[]

# %%
v_button = driver.find_element_by_xpath('/html/body/table[1]/tbody/tr/td[2]/span[2]/a').get_attribute('href')
driver.get(v_button)

# %%
title=driver.find_elements_by_xpath(r'//tr[@bgcolor="DDEEFF"]/td[1]')
for i in title:
    Dataset_name.append(i.text)
    
    
dt=driver.find_elements_by_xpath(r'//tr[@bgcolor="DDEEFF"]/td[2]')
for i in dt:
    Data_type.append(i.text)

t=driver.find_elements_by_xpath(r'//tr[@bgcolor="DDEEFF"]/td[3]')
for i in t:
    Task.append(i.text)

at=driver.find_elements_by_xpath(r'//tr[@bgcolor="DDEEFF"]/td[4]')
for i in at:
    Attribute_type.append(i.text)
    

nn=driver.find_elements_by_xpath(r'//tr[@bgcolor="DDEEFF"]/td[5]')
for i in nn:
    instances.append(i.text)

    
a=driver.find_elements_by_xpath(r'//tr[@bgcolor="DDEEFF"]/td[6]')
for i in a:
    attribute.append(i.text) 
    
y=driver.find_elements_by_xpath(r'//tr[@bgcolor="DDEEFF"]/td[7]')
for i in y:
    Year.append(i.text)

# %%
print(len(Dataset_name),len(Data_type),len(Task),len(Attribute_type),len(instances),len(attribute),len(Year))
# Out:
# 280 280 280 280 280 280 280

# %%
datasets=pd.DataFrame({})
datasets['Dataset_name']=Dataset_name
datasets['Data_type']=Data_type
datasets['Task']=Task
datasets['Attribute_type']=Attribute_type
datasets['instances']=instances
datasets['attribute']=attribute
datasets['Year']=Year
datasets
# Out:
#                                           Dataset_name      Data_type  \
# 0                                              Abalone  Multivariate
# 1                                                Adult  Multivariate
# 2                         Anonymous Microsoft Web Data
# 3                                Artificial Characters  Multivariate
# 4                             Audiology (Standardized)  Multivariate
# ..                                                 ...            ...
# 275    Shoulder Implant X-Ray Manufacturer Classifi...  Multivariate
# 276                                           HCV data  Multivariate
# 277                       South German Credit (UPDATE)  Multivariate
# 278                     Guitar Chords finger positions          Text
# 279                                        Codon usage  Multivariate
#
#                                         Task               Attribute_type  \
# 0                            Classification   Categorical, Integer, Real
# ...
